# %%
# import pickle
# # generamos un diccionario con los nombres de los objetos a guardar y los objetos a guardar
# data = {
#     'x_train': x_train,
#     'y_train': y_train,
#     'x_test': x_test,
#     'y_test': y_test,
# }

# models ={
#     'best_iso_for': best_iso_for,
#     'best_clas_prunned_tree': best_prunned_clas_tree,
#     'best_rf': best_rf,
#     'best_et': best_et,
#     'best_ada': best_ada,
#     'best_gb': best_gb,
#     'best_hgb': best_hgb,
#     'cat_boost': cb_class
# }

# # Guardamos los objetos utilizando pickle
# with open('../data/data.pkl', 'wb') as file:
#     pickle.dump(data, file)

# with open('../data/models.pkl', 'wb') as file:
#     pickle.dump(models, file)

# %%
import pickle
# Cargamos los objetos guardados utilizando pickle
with open('../data/data.pkl', 'rb') as file:
    data = pickle.load(file)

# Cargamos la data
x_train = data['x_train']
y_train = data['y_train']
x_test = data['x_test']
y_test = data['y_test']

# Cargamos los modelos guardados utilizando pickle
with open('../data/models.pkl', 'rb') as file:
    models = pickle.load(file)
best_iso_for = models['best_iso_for']
best_clas_prunned_tree = models['best_clas_prunned_tree']
best_rf = models['best_rf']
best_et = models['best_et']
best_ada = models['best_ada']
best_gb = models['best_gb']
best_hgb = models['best_hgb']
